# %%
with open('tfidf.txt', 'r') as myfile:
    data=myfile.read().replace('\n', ' ')

# %%
sample_text=data.lower()

# %%
tokens= [word  for word in sample_text.split()]

# %%
import nltk as nl

# %%
tokens= nl.word_tokenize(sample_text)

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
tokens=tokenizer.tokenize(sample_text)

# %%
token_freq=nl.FreqDist(tokens)

# %%
token_freq
# Out:
# FreqDist({'the': 95, 'we': 80, 'to': 66, 'okay': 58, 'is': 56, 's': 55, 'so': 48, 'that': 45, 'and': 43, 'have': 40, ...})

# %%
# %matplotlib inline
token_freq.plot(30,cumulative=False)

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

# %%
def remove_stopwords(words):
    filtered_words=[]
    for word in words:
        if word not in stop_words:
            filtered_words.append(word)
            
    return filtered_words
print(remove_stopwords(tokens))
# Out:
# ['hi', 'guys', 'jonathan', 'lambert', 'mathematics', 'development', 'support', 'service', 'national', 'college', 'ireland', 'short', 'video', 'well', 'hope', 'going', 'short', 'going', 'deal', 'derivation', 'slope', 'intercept', 'parameters', 'regression', 'line', 'best', 'fit', 'okay', 'problem', 'n', 'observations', 'important', 'n', 'paired', 'observations', 'across', 'two', 'variables', 'independent', 'dependent', 'variable', 'okay', 'let', 'say', 'argument', 'sake', 'independent', 'independent', 'variable', 'okay', 'symbolized', 'x', 'dependent', 'variable', 'variable', 'symbolized', 'okay', 'n', 'paired', 'observations', 'observations', 'across', 'particular', 'variables', 'okay', 'paired', 'observations', 'suppose', 'could', 'could', 'produce', 'scatter', 'plot', 'okay', 'could', 'produce', 'scatter', 'plot', 'okay', 'looks', 'something', 'like', 'x', 'axis', 'axis', 'showing', 'first', 'quadrant', 'necessarily', 'first', 'quadrant', 'n', 'observations', 'associate', 'x', 'let', 'say', 'argument', 'sake', 'first', 'observation', 'let', 'say', 'x1', 'y1', 'say', 'second', 'observation', 'let', 'say', 'x2', 'y2', 'let', 'say', 'old', 'observation', 'let', 'say', 'x3', 'y3', 'n', 'observations', 'okay', 'let', 'say', 'n', 'observations', 'say', 'nth', 'observation', 'x', 'n', 'okay', 'n', 'observations', 'want', 'want', 'try', 'identify', 'line', 'goes', 'particular', 'dataset', 'okay', 'define', 'best', 'fit', 'line', 'dataset', 'mean', 'best', 'fit', 'line', 'draw', 'line', 'dataset', 'something', 'like', 'best', 'lyon', 'draw', 'best', 'fit', 'line', 'dataset', 'okay', 'distance', 'square', 'distance', 'observation', 'okay', 'line', 'made', 'square', 'distance', 'named', 'importantly', 'sum', 'squared', 'distances', 'okay', 'minimized', 'okay', 'means', 'matter', 'line', 'plot', 'better', 'line', 'whose', 'sum', 'squared', 'distances', 'smallest', 'value', 'okay', 'let', 'assume', 'best', 'fit', 'line', 'let', 'assume', 'okay', 'best', 'fit', 'regression', 'line', 'regression', 'line', 'predictive', 'line', 'let', 'say', 'hat', 'equal', 'let', 'say', 'c', 'plus', 'mx', 'okay', 'line', 'intercept', 'form', 'okay', 'values', 'equal', 'c', 'plus', 'times', 'x', 'c', 'defined', 'well', 'c', 'line', 'intersects', 'axis', 'point', 'okay', 'slope', 'line', 'okay', 'assuming', 'okay', 'let', 'concentrate', 'one', 'particular', 'point', 'respect', 'particular', 'line', 'let', 'redo', 'particular', 'scatter', 'plot', 'okay', 'going', 'concentrate', 'one', 'particular', 'point', 'latent', 'x', 'axis', 'line', 'best', 'fit', 'line', 'best', 'fit', 'let', 'say', 'point', 'say', 'argument', 'sake', 'x1', 'y1', 'line', 'line', 'hat', 'equal', 'c', 'plus', 'x', 'okay', 'know', 'real', 'observation', 'particular', 'point', 'okay', 'real', 'observation', 'observation', 'value', 'independent', 'variable', 'symbolized', 'x1', 'observation', 'associated', 'value', 'variable', 'symbolized', 'y1', 'okay', 'real', 'okay', 'best', 'fit', 'lie', 'line', 'okay', 'trying', 'represents', 'line', 'goes', 'data', 'set', 'minimum', 'squared', 'distance', 'observations', 'away', 'line', 'okay', 'predictive', 'power', 'okay', 'substitute', 'value', 'independent', 'variable', 'get', 'associated', 'predicted', 'value', 'back', 'okay', 'substitute', 'x', '1', 'particular', 'line', 'okay', 'well', 'x', '1', 'gets', 'substituted', 'line', 'line', 'going', 'predict', 'value', 'okay', 'respect', 'x', '1', 'value', 'hat', 'first', 'observation', 'half', '1', 'okay', 'talk', 'squared', 'distances', 'really', 'talking', 'distance', 'okay', '1', 'minus', '1', 'hats', 'predicted', 'value', 'squared', 'sum', 'distances', 'across', 'line', 'needs', 'minimized', 'okay', 'right', 'n', 'observations', 'squared', 'distances', 'look', 'like', 'okay', 'well', 'n', 'observation', 'going', 'n', 'values', 'yes', 'together', 'ok', 'let', 'rewrite', 'okay', 'regression', 'line', 'going', 'sum', 'squared', 'errors', 'line', 'going', 'equal', 'going', 'equal', 'point', 'going', ' ...

# %%
# %matplotlib inline 
token_freq= nl.FreqDist(remove_stopwords(tokens))
token_freq.plot(20, cumulative=False)

# %%
bigrams=nl.bigrams(remove_stopwords(tokens))
token_freq=nl.FreqDist(bigrams)
result = []
for token  in token_freq.keys():
    result.append((token,token_freq[token]))

# %%
import numpy as np 
np.savetxt("Labled1.csv", result, delimiter=",,", fmt='%s')

# %%
result
# Out:
# [(('hi', 'guys'), 1),
#  (('guys', 'jonathan'), 1),
#  (('jonathan', 'lambert'), 1),
#  (('lambert', 'mathematics'), 1),
#  (('mathematics', 'development'), 1),
#  (('development', 'support'), 1),
#  (('support', 'service'), 1),
#  (('service', 'national'), 1),
#  (('national', 'college'), 1),
#  (('college', 'ireland'), 1),
#  (('ireland', 'short'), 1),
#  (('short', 'video'), 1),
#  (('video', 'well'), 1),
#  (('well', 'hope'), 1),
#  (('hope', 'going'), 1),
#  (('going', 'short'), 1),
#  (('short', 'going'), 1),
#  (('going', 'deal'), 1),
#  (('deal', 'derivation'), 1),
#  (('derivation', 'slope'), 1),
#  (('slope', 'intercept'), 1),
#  (('intercept', 'parameters'), 1),
#  (('parameters', 'regression'), 1),
#  (('regression', 'line'), 4),
#  (('line', 'best'), 3),
#  (('best', 'fit'), 11),
#  (('fit', 'okay'), 1),
#  (('okay', 'problem'), 1),
#  (('problem', 'n'), 1),
#  (('n', 'observations'), 6),
#  (('observations', 'important'), 1),
#  (('important', 'n'), 1),
#  (('n', 'paired'), 2),
#  (('paired', 'observations'), 3),
#  (('observations', 'across'), 2),
#  (('across', 'two'), 1),
#  (('two', 'variables'), 1),
#  (('variables', 'independent'), 1),
#  (('independent', 'dependent'), 1),
#  (('dependent', 'variable'), 2),
#  (('variable', 'okay'), 2),
#  (('okay', 'let'), 6),
#  (('let', 'say'), 10),
#  (('say', 'argument'), 3),
#  (('argument', 'sake'), 3),
#  (('sake', 'independent'), 1),
#  (('independent', 'independent'), 1),
#  (('independent', 'variable'), 3),
#  (('okay', 'symbolized'), 1),
#  (('symbolized', 'x'), 1),
#  (('x', 'dependent'), 1),
#  (('variable', 'variable'), 1),
#  (('variable', 'symbolized'), 3),
#  (('symbolized', 'okay'), 1),
#  (('okay', 'n'), 2),
#  (('observations', 'observations'), 1),
#  (('across', 'particular'), 1),
#  (('particular', 'variables'), 1),
#  (('variables', 'okay'), 1),
#  (('okay', 'paired'), 1),
#  (('observations', 'suppose'), 1),
#  (('suppose', 'could'), 1),
#  (('could', 'could'), 1),
#  (('could', 'produce'), 2),
#  (('produce', 'scatter'), 2),
#  (('scatter', 'plot'), 3),
#  (('plot', 'okay'), 3),
#  (('okay', 'could'), 1),
#  (('okay', 'looks'), 1),
#  (('looks', 'something'), 1),
#  (('something', 'like'), 2),
#  (('like', 'x'), 1),
#  (('x', 'axis'), 2),
#  (('axis', 'axis'), 1),
#  (('axis', 'showing'), 1),
#  (('showing', 'first'), 1),
#  (('first', 'quadrant'), 2),
#  (('quadrant', 'necessarily'), 1),
#  (('necessarily', 'first'), 1),
#  (('quadrant', 'n'), 1),
#  (('observations', 'associate'), 1),
#  (('associate', 'x'), 1),
#  (('x', 'let'), 1),
#  (('sake', 'first'), 1),
#  (('first', 'observation'), 3),
#  (('observation', 'let'), 3),
#  (('say', 'x1'), 1),
#  (('x1', 'y1'), 2),
#  (('y1', 'say'), 1),
#  (('say', 'second'), 1),
#  (('second', 'observation'), 2),
#  (('say', 'x2'), 1),
#  (('x2', 'y2'), 1),
#  (('y2', 'let'), 1),
#  (('say', 'old'), 1),
#  (('old', 'observation'), 1),
#  (('say', 'x3'), 1),
#  (('x3', 'y3'), 1),
#  (('y3', 'n'), 1),
#  (('observations', 'okay'), 1),
#  (('say', 'n'), 1),
#  (('observations', 'say'), 1),
#  (('say', 'nth'), 1),
#  (('nth', 'observation'), 1),
#  (('observation', 'x'), 1),
#  (('x', 'n'), 2),
#  (('n', 'okay'), 2),
#  (('observations', 'want'), 1),
#  (('want', 'want'), 1),
#  (('want', 'try'), 1),
#  (('try', 'identify'), 1),
#  (('identify', 'line'), 1),
#  (('line', 'goes'), 2),
#  (('goes', 'particular'), 1),
#  (('particular', 'dataset'), 1),
#  (('dataset', 'okay'), 2),
#  (('okay', 'define'), 1),
#  (('define', 'best'), 1),
#  (('fit', 'line'), 6),
#  (('line', 'dataset'), 3),
#  (('dataset', 'mean'), 1),
#  (('mean', 'best'), 1),
#  (('line', 'draw'), 1),
#  (('draw', 'line'), 1),
#  (('dataset', 'something'), 1),
#  (('like', 'best'), 1),
#  (('best', 'lyon'), 1),
#  (('lyon', 'draw'), 1),
#  (('draw', 'best'), 1),
#  (('okay', 'distance'), 1),
#  (('distance', 'square'), 1),
#  (('square', 'distance'), 2),
#  (('distance', 'observation'), 1),
#  (('observation', 'okay'), 1),
#  (('okay', 'line'), 2),
#  (('line', 'made'), 1),
#  (('made', 'square'), 1),
#  (('distance', 'named'), 1),
#  (('named', 'importantly'), 1),
#  (('importantly', 'sum'), 1),
#  (('sum', 'squared'), 4),
#  (('squared', 'distances'), 4),
#  (('distances', 'okay'), 1),
#  (('okay', 'minimized'), 1),
#  (('minimized', 'okay'), 2),
#  (('okay', 'means'), 1),
#  (('means', 'matter'), 1),
#  (('matter', 'line'), 1),
#  (('line', 'plot'), 1),
#  (('plot', 'better'), 1),
#  (('better', 'line'), 1),
#  (('line', 'whose'), 1),
#  (('whose', 'sum'), 1),
#  (('distances', 'smallest'), 1),
#  (('smallest', 'value'), 1),
#  (('value', 'okay'), 4),
#  (('let', 'assume'), 2),
#  (('assume', 'best'), 1),
#  (('line', 'let'), 3),
#  (('assume', 'okay'), 1),
#  (('okay', 'best'), 2),
#  (('fit', 'regression'), 2),
#  (('line', 'regression'), 1),
#  (('line', 'predictive'), 1),
#  (('predictive', 'line'), 1),
#  (('say', 'hat'), 1),
#  (('hat', 'equal'), 3),
#  (('equal', 'let'), 1),
#  (('say', 'c'), 1),
#  (('c', 'plus'), 25),
#  (('plus', 'mx'), 15),
#  (('mx', 'okay'), 2),
#  (('line', 'intercept'), 1),
#  (('intercept', 'form'), 1),
#  (('form', 'okay'), 1),
#  (('okay', 'values'), 1),
#  (('values', 'equal'), 1),
#  (('equal', 'c'), 4),
#  (('plus', 'times'), 1),
#  (('times', 'x'), 1),
#  (('x', 'c'), 2),
#  (('c', 'defined'), 1),
#  (('defined', 'well'), 1),
#  (('well', 'c'), 1),
#  (('c', 'line'), 1),
#  (('line', 'intersects'), 1),
#  (('intersects', 'axis'), 1),
#  (('axis', 'point'), 1),
#  (('point', 'okay'), 2),
#  (('okay', 'slope'), 1),
#  (('slope', 'line'), 1),
#  (('line', 'okay'), 7),
#  (('okay', 'assuming'), 1),
#  (('assuming', 'okay'), 2),
#  (('let', 'concentrate'), 1),
#  (('concentrate', 'one'), 2),
#  (('one', 'particular'), 2),
#  (('particular', 'point'), 3),
#  (('point', 'respect'), 1),
#  (('respect', 'particular'), 1),
#  (('particular', 'line'), 2),
#  (('let', 'redo'), 1),
#  (('redo', 'particular'), 1),
#  (('particular', 'scatter'), 1),
#  (('okay', 'going'), 3),
#  (('going', 'concentrate'), 1),
#  (('point', 'latent'), 1),
#  (('latent', 'x'), 1),
#  (('axis', 'line'), 1),
#  (('fit', 'let'), 1),
#  (('say', 'point'), 1),
#  (('point', 'say'), 1),
#  (('sake', 'x1'), 1),
#  (('y1', 'line'), 1),
#  (('line', 'line'), 2),
#  (('line', 'hat'), 2),
#  (('plus', 'x'), 4),
#  (('x', 'okay'), 1),
#  (('okay', 'know'), 2),
#  (('know', 'real'), 1),
#  (('real', 'observation'), 2),
#  (('observation', 'particular'), 1),
#  (('okay', 'real'), 2),
#  (('observation', 'observation'), 1),
#  (('observation', 'value'), 1),
#  (('value', 'independent'), 2),
#  (('symbolized', 'x1'), 1),
#  (('x1', 'observation'), 1),
#  (('observation', 'associated'), 1),
#  (('associated', 'value'), 1),
#  (('value', 'variable'), 1),
#  (('symbolized', 'y1'), 1),
#  (('y1', 'okay'), 1),
#  (('real', 'okay'), 1),
#  (('fit', 'lie'), 1),
#  (('lie', 'line'), 1),
#  (('okay', 'trying'), 1),
#  (('trying', 'represents'), 1),
#  (('represents', 'line'), 1),
#  (('goes', 'data'), 1),
#  (('data', 'set'), 1),
#  (('set', 'minimum'), 1),
#  (('minimum', 'squared'), 1),
#  (('squared', 'distance'), 1),
#  (('distance', 'observations'), 1),
#  (('observations', 'away'), 1),
#  (('away', 'line'), 1),
#  (('okay', 'predictive'), 1),
#  (('predictive', 'power'), 1),
#  (('power', 'okay'), 1),
#  (('okay', 'substitute'), 3),
#  (('substitute', 'value'), 1),
#  (('variable', 'get'), 1),
#  (('get', 'associated'), 1),
#  (('associated', 'predicted'), 1),
#  (('predicted', 'value'), 8),
#  (('value', 'back'), 2),
#  (('back', 'okay'), 1),
#  (('substitute', 'x'), 2),
#  (('x', '1'), 5),
#  (('1', 'particular'), 1),
#  (('okay', 'well'), 2),
#  (('well', 'x'), 1),
#  (('1', 'gets'), 1),
#  (('gets', 'substituted'), 1),
#  (('substituted', 'line'), 1),
#  (('line', 'going'), 5),
#  (('going', 'predict'), 1),
#  (('predict', 'value'), 1),
#  (('okay', 'respect'), 1),
#  (('respect', 'x'), 1),
#  (('1', 'value'), 1),
#  (('value', 'hat'), 1),
#  (('hat', 'first'), 2),
#  (('observation', 'half'), 1),
#  (('half', '1'), 1),
#  (('1', 'okay'), 3),
#  (('okay', 'talk'), 1),
#  (('talk', 'squared'), 1),
#  (('distances', 'really'), 1),
#  (('really', 'talking'), 1),
#  (('talking', 'distance'), 1),
#  (('distance', 'okay'), 2),
#  (('okay', '1'), 1),
#  (('1', 'minus'), 4),
#  (('minus', '1'), 1),
#  (('1', 'hats'), 1),
#  (('hats', 'predicted'), 1),
#  (('value', 'squared'), 2),
#  (('squared', 'sum'), 1),
#  (('sum', 'distances'), 1),
#  (('distances', 'across'), 1),
#  (('across', 'line'), 4),
#  (('line', 'needs'), 1),
#  (('needs', 'minimized'), 1),
#  (('okay', 'right'), 1),
#  (('right', 'n'), 1),
#  (('observations', 'squared'), 1),
#  (('distances', 'look'), 1),
#  (('look', 'like'), 1),
#  (('like', 'okay'), 1),
#  (('well', 'n'), 1),
#  (('n', 'observation'), 1),
#  (('observation', 'going'), 1),
#  (('going', 'n'), 5),
#  (('n', 'values'), 1),
#  (('values', 'yes'), 1),
#  (('yes', 'together'), 1),
#  (('together', 'ok'), 1),
#  (('ok', 'let'), 1),
#  (('let', 'rewrite'), 1),
#  (('rewrite', 'okay'), 1),
#  (('okay', 'regression'), 1),
#  (('going', 'sum'), 1),
#  (('squared', 'errors'), 2),
#  (('errors', 'line'), 1),
#  (('going', 'equal'), 5),
#  (('equal', 'going'), 1),
#  (('equal', 'point'), 1),
#  (('point', 'going'), 3),
#  (('going', 'distance'), 1),
#  (('okay', 'points'), 1),
#  (('points', 'value'), 1),
#  (('value', 'away'), 1),
#  (('away', 'predicted'), 1),
#  (('value', 'square'), 1),
#  (('square', 'first'), 1),
#  (('first', 'point'), 1),
#  (('going', '1'), 2),
#  (('minus', 'hat'), 3),
#  (('first', 'value'), 1),
#  (('squared', 'plus'), 3),
#  (('plus', 'second'), 3),
#  (('second', 'point'), 2),
#  (('going', '2'), 3),
#  (('2', 'minus'), 4),
#  (('hat', '2'), 1),
#  (('2', 'squared'), 2),
#  (('squared', 'way'), 1),
#  (('way', 'nth'), 1),
#  (('nth', 'value'), 3),
#  (('value', 'going'), 2),
#  (('n', 'minus'), 3),
#  (('hat', 'predicted'), 1),
#  (('value', 'nth'), 1),
#  (('okay', 'squared'), 1),
#  (('squared', 'okay'), 1),
#  (('know', 'particular'), 1),
#  (('particular', 'hat'), 1),
#  (('hat', 'values'), 1),
#  (('values', 'guff'), 1),
#  (('guff', 'best'), 1),
#  (('regression', 'assuming'), 1),
#  (('assuming', 'know'), 1),
#  (('know', 'hat'), 1),
#  (('hat', 'e'), 1),
#  (('e', 'c'), 1),
#  (('okay', 'particular'), 1),
#  (('particular', 'information'), 1),
#  (('information', 'gave'), 1),
#  (('gave', 'progression'), 1),
#  (('progression', 'line'), 1),
#  (('mx', 'know'), 1),
#  (('know', 'put'), 1),
#  (('put', 'first'), 1),
#  (('observation', 'substitute'), 1),
#  (('1', 'know'), 1),
#  (('know', 'get'), 1),
#  (('get', 'back'), 1),
#  (('back', 'get'), 1),
#  (('get', 'hat'), 1),
#  (('hat', '1'), 1),
#  (('1', 'equal'), 1),
#  (('okay', 'put'), 1),
#  (('put', 'force'), 1),
#  (('force', 'observation'), 1),
#  (('observation', 'best'), 1),
#  (('line', 'get'), 1),
#  (('get', 'first'), 1),
#  (('first', 'predicted'), 1),
#  (('value', 'substitute'), 1),
#  (('substitute', 'second'), 1),
#  (('observation', 'get'), 2),
#  (('get', 'second'), 1),
#  (('second', 'predicted'), 1),
#  (('substitute', 'enth'), 1),
#  (('enth', 'observation'), 1),
#  (('get', 'substitute'), 1),
#  (('substitute', 'end'), 1),
#  (('end', 'observation'), 1),
#  (('observation', 'ben'), 1),
#  (('ben', 'substitute'), 1),
#  (('substitute', 'get'), 1),
#  (('get', 'nth'), 1),
#  (('nth', 'predicted'), 1),
#  (('back', 'ok'), 1),
#  (('ok', 'one'), 1),
#  (('one', 'terms'), 1),
#  (('terms', 'suppose'), 1),
#  (('suppose', 'reduced'), 1),
#  (('reduced', 'okay'), 1),
#  (('okay', 'substituting'), 1),
#  (('substituting', 'predicted'), 1),
#  (('predicted', 'values'), 2),
#  (('values', 'know'), 1),
#  (('know', 'predicted'), 1),
#  (('values', 'particular'), 1),
#  (('particular', 'best'), 1),
#  (('best', 'line'), 1),
#  (('line', 'assuming'), 1),
#  (('okay', 'tells'), 1),
#  (('tells', 'us'), 1),
#  (('us', 'standard'), 1),
#  (('standard', 'error'), 2),
#  (('error', 'start'), 1),
#  (('start', 'standard'), 1),
#  (('error', 'sum'), 1),
#  (('errors', 'across'), 1),
#  (('equal', 'first'), 2),
#  (('first', 'term'), 5),
#  (('term', 'must'), 1),
#  (('must', 'y1'), 1),
#  (('y1', 'minus'), 2),
#  (('minus', 'well'), 1),
#  (('well', '1'), 1),
#  (('1', 'hat'), 1),
#  (('hat', 'c'), 1),
#  (('plus', 'x1'), 2),
#  (('x1', '2'), 1),
#  (('2', 'b'), 2),
#  (('b', 'squared'), 2),
#  (('plus', 'next'), 1),
#  (('next', 'predicted'), 1),
#  (('value', 'next'), 1),
#  (('next', 'sum'), 1),
#  (('sum', 'squares'), 6),
#  (('squares', 'going'), 1),
#  (('minus', 'c'), 12),
#  (('mx', '2'), 5),
#  (('2', '2'), 2),
#  (('plus', 'nth'), 1),
#  (('plus', 'xn'), 1),
#  (('xn', 'squared'), 1),
#  (('squared', 'ok'), 2),
#  (('ok', 'another'), 1),
#  (('another', 'form'), 1),
#  (('form', 'represents'), 1),
#  (('represents', 'particular'), 1),
#  (('particular', 'sum'), 1),
#  (('squares', 'take'), 1),
#  (('take', 'terms'), 1),
#  (('terms', 'squared'), 1),
#  (('squared', 'let'), 1),
#  (('let', 'val'), 1),
#  (('val', 'jabrai'), 1),
#  (('jabrai', 'let'), 1),
#  (('let', 'expand'), 1),
#  (('expand', 'little'), 1),
#  (('little', 'bit'), 1),
#  (('bit', 'okay'), 1),
#  (('okay', 'end'), 1),
#  (('end', 'sum'), 1),
#  (('squares', 'error'), 2),
#  (('error', 'across'), 2),
#  (('term', 'going'), 3),
#  (('going', 'going'), 2),
#  (('mx', '1'), 5),
#  (('okay', 'times'), 1),
#  (('times', 'y1'), 5),
#  (('plus', 'nx'), 3),
#  (('nx', 'x1'), 1),
#  (('x1', 'plus'), 1),
#  (('second', 'term'), 3),
#  (('term', 'squared'), 2),
#  (('squared', 'going'), 1),
#  (('2', 'times'), 2),
#  (('times', '2'), 1),
#  (('2', 'ok'), 1),
#  (('ok', 'plus'), 1),
#  (('plus', 'way'), 1),
#  (('way', 'true'), 1),
#  (('true', 'nth'), 1),
#  (('nth', 'term'), 3),
#  (('mx', 'n'), 3),
#  (('n', 'times'), 3),
#  (('times', 'yn'), 1),
#  (('yn', 'minus'), 1),
#  (('x', 'mx'), 1),
#  (('n', 'ok'), 1),
#  (('ok', 'small'), 1),
#  (('small', 'bit'), 1),
#  (('bit', 'algebra'), 1),
#  (('algebra', 'step'), 1),
#  (('step', 'step'), 1),
#  (('step', 'okay'), 1),
#  (('okay', 'multiply'), 1),
#  (('multiply', 'particular'), 1),
#  (('particular', 'brackets'), 1),
#  (('brackets', 'okay'), 1),
#  (('okay', 'sum'), 1),
#  (('equal', 'well'), 1),
#  (('well', 'ignore'), 1),
#  (('ignore', 'everything'), 1),
#  (('everything', 'else'), 1),
#  (('else', 'assume'), 1),
#  (('assume', 'consider'), 1),
#  (('consider', 'particular'), 1),
#  (('particular', 'product'), 1),
#  (('product', 'first'), 1),
#  (('term', 'times'), 1),
#  (('times', 'first'), 1),
#  (('term', 'y1'), 1),
#  (('y1', 'times'), 3),
#  (('y1', 'going'), 1),
#  (('going', 'y1'), 1),
#  (('y1', 'x'), 2),
#  (('x', 'minus'), 3),
#  (('c', 'times'), 1),
#  (('times', 'c'), 7),
#  (('mx', 'one'), 2),
#  (('one', 'going'), 1),
#  (('going', 'minus'), 1),
#  (('x1', 'times'), 1),
#  (('y1', 'gonna'), 1),
#  (('gonna', 'minus'), 1),
#  (('minus', 'x'), 1),
#  (('minus', 'plus'), 2),
#  (('plus', 'going'), 2),
#  (('going', 'cm'), 1),
#  (('cm', 'x'), 2),
#  (('x', 'one'), 2),
#  (('one', 'times'), 1),
#  (('times', 'cm'), 1),
#  (('one', 'okay'), 2),
#  (('okay', 'y1'), 1),
#  (('y1', 'gives'), 1),
#  (('gives', 'us'), 2),
#  (('us', '1'), 1),
#  (('1', 'squared'), 1),
#  (('ok', 'y1'), 1),
#  (('one', 'gives'), 1),
#  (('us', 'minus'), 1),
#  (('minus', 'y1'), 1),
#  (('1', 'times'), 3),
#  (('y1', 'actually'), 1),
#  (('actually', 'two'), 1),
#  (('two', 'end'), 1),
#  (('end', 'minus'), 1),
#  (('minus', '2y'), 1),
#  (('2y', '1'), 1),
#  (('nx', 'one'), 1),
#  (('okay', 'finally'), 1),
#  (('finally', 'minus'), 1),
#  (('minus', 'times'), 1),
#  (('times', 'minus'), 1),
#  (('plus', 'term'), 1),
#  (('squared', 'ac'), 1),
#  (('ac', 'plus'), 1),
#  (('mx', 'mx'), 1),
#  (('1', 'plus'), 1),
#  (('plus', 'ok'), 1),
#  (('ok', 'first'), 1),
#  (('term', 'expanded'), 1),
#  (('expanded', 'plus'), 1),
#  (('term', 'expand'), 1),
#  (('expand', 'going'), 1),
#  (('going', 'term'), 1),
#  (('term', 'except'), 1),
#  (('except', 'identifier'), 1),
#  (('identifier', 'going'), 1),
#  (('going', 'change'), 1),
#  (('change', 'second'), 1),
#  (('point', 'instead'), 1),
#  (('instead', 'subscript'), 1),
#  (('subscript', 'ones'), 1),
#  (('ones', 'going'), 1),
#  (('going', 'subscript'), 1),
#  (('subscript', 'stools'), 1),
#  (('stools', 'becomes'), 1),
#  (('becomes', '2'), 1),
#  (('squared', 'minus'), 1),
#  (('minus', '2'), 1),
#  (('2', 'x'), 1),
#  (('c', 'x'), 1),
#  (('x', '2'), 1),
#  (('2', 'c'), 1),
#  (('c', 'mx'), 2),
#  (('2', 'going'), 1),
#  (('going', 'second'), 1),
#  (('term', 'nearly'), 1),
#  (('nearly', 'expanded'), 1),
#  (('expanded', 'way'), 1),
#  (('way', 'tune'), 1),
#  (('tune', 'nth'), 1),
#  (('going', 'situation'), 1),
#  (('situation', 'going'), 1),
#  (('n', 'squared'), 1),
#  (('squared', '2'), 1),
#  (('2', 'n'), 1),
#  (('okay', 'plus'), 1),
#  (('going', 'c'), 1),
#  (('nx', 'n'), 1),
#  (('n', 'nth'), 1),
#  (('term', 'okay'), 1),
#  (('okay', 'earlier'), 1),
#  (('earlier', 'expand'), 1),
#  (('expand', 'particular'), 1),
#  (('particular', 'products'), 1),
#  (('products', 'okay'), 1),
#  (('let', 'move'), 1),
#  (('move', 'okay'), 1),
#  (('let', 'try'), 1),
#  (('try', 'expand'), 1),
#  (('expand', 'products'), 1),
#  (('products', 'sum'), 1),
#  (('squares', 'line'), 2),
#  (('okay', 'leave'), 1),
#  (('leave', 'sum'), 1)]
